# %% [markdown]
# <a href="https://colab.research.google.com/github/AlaaSoudy/Linear-Polynomial-Regression/blob/main/Linear_%26_Polynomial_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing
from sklearn.linear_model import SGDRegressor, LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from mpl_toolkits.mplot3d import Axes3D
import torch
import torch.nn as nn
import torch.optim as optim

# %%
plt.style.use('dark_background')

# %%
x=np.arange(1,11)
y=np.arange(1,11)

# %%
np.random.seed(2)
w=np.random.rand(1)[0]
b=np.random.rand(1)[0]

# %%
eta=.001
epochs=1000
cost_val=np.zeros(epochs)

# %%
for i in range(epochs):
    y_pred=w*x+b
    w=w+eta*(1/len(x))*np.sum(x*(y-y_pred))
    b=b+eta*(1/len(x))*np.sum(y-y_pred)

    cast=np.mean(np.square(y-y_pred))
    cost_val[i]=cast
    if cast <1e-5:
      break

# %%
x_vals=np.arange(-10,11)
y_vals=w*x_vals+b

# %%
plt.plot(x_vals, y_vals , 'r-')
plt.xlabel('x_vales')
plt.ylabel('y_vales')
plt.legend()
plt.grid(True ,alpha =.1)
plt.show();

# %%
plt.figure(figsize=(10,9) , dpi=100)
plt.subplot(1,2 ,1)
plt.plot(x,y,'oy-', markersize=8, label="Data points")
plt.grid(True ,alpha =.1)
plt.xlabel('x_vales')
plt.ylabel('y_vales')
plt.legend()
plt.tight_layout()
plt.subplot(1,2,2)
plt.plot(range(1,i+2) , cost_val[:i+1])
plt.xlabel('Epochs')
plt.ylabel('Cost')
plt.grid(True ,alpha =.1)
plt.tight_layout()
plt.show()
